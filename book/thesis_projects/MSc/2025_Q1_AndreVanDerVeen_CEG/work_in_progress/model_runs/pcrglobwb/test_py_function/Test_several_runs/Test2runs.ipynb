# %% [markdown]
# # Test 2 runs with .py functions

# %%
# setup imports
import sys
from pathlib import Path
from tqdm.notebook import tqdm 
from datetime import datetime

PROJECT_ROOT = Path().resolve().parents[3]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

from src.paths import *
from src.models import run_PCRGLOBWB_model

import ewatercycle.forcing
import ewatercycle.parameter_sets
import ewatercycle.models
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498

# %%
experiment_start_date = "1949-01-01T00:00:00Z"
experiment_end_date = "1950-12-31T00:00:00Z"

prepared_PCRGlob_forcing = FORCING_PCRGLOB / LOAD_PCR /PCR_TAIL


run_PCRGLOBWB_model(prepared_PCRGlob_forcing, "2rivers_clone.ini", experiment_start_date,experiment_end_date )
# Out:
# starting model, might take a minute or so
# Running model:   0%|          | 0/729 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 7
#       2 experiment_end_date = "1950-12-31T00:00:00Z"
#       4 prepared_PCRGlob_forcing = FORCING_PCRGLOB / LOAD_PCR /PCR_TAIL
# ----> 7 run_PCRGLOBWB_model(prepared_PCRGlob_forcing, "2rivers_clone.ini", experiment_start_date,experiment_end_date )
#
# File ~/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/src/models.py:184, in run_PCRGLOBWB_model(forcing_path, ini_name, start_date, end_date)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/model.py:182, in eWaterCycleModel.update(self)
#     180 def update(self) -> None:
#     181     """Advance model state by one time step."""
# --> 182     self._bmi.update()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_optionaldest.py:52, in OptionalDestBmi.update(self)
#      51 def update(self) -> None:
# ---> 52     self.origin.update()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_memoized.py:60, in MemoizedBmi.update(self)
#      59 def update(self):
# ---> 60     self.origin.update()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/container.py:490, in BmiProxy.update(self)
#     489 def update(self) -> None:
# --> 490     return self.origin.update()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py:105, in BmiClient.update(self)
#     103 def update(self):
#     104     try:
# --> 105         self.stub.update(bmi_pb2.Empty())
#     106     except grpc.RpcError as e:
#     107         handle_error(e)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py:1173, in _UnaryUnaryMultiCallable.__call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1161 def __call__(
#    1162     self,
#    1163     request: Any,
#    (...)
#    1168     compression: Optional[grpc.Compression] = None,
#    1169 ) -> Any:
#    1170     (
#    1171         state,
#    1172         call,
# -> 1173     ) = self._blocking(
#    1174         request, timeout, metadata, credentials, wait_for_ready, compression
#    1175     )
#    1176     return _end_unary_response_blocking(state, call, False, None)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_channel.py:1157, in _UnaryUnaryMultiCallable._blocking(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1141 state.target = _common.decode(self._target)
#    1142 call = self._channel.segregated_call(
#    1143     cygrpc.PropagationConstants.GRPC_PROPAGATE_DEFAULTS,
#    1144     self._method,
#    (...)
#    1155     self._context,
#    1156 )
# -> 1157 event = call.next_event()
#    1158 _handle_event(event, state, self._response_deserializer)
#    1159 return state, call
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:367, in grpc._cython.cygrpc.SegregatedCall.next_event()
#
# File src/python/grpcio/grpc/_cython/_cygrpc/channel.pyx.pxi:190, in grpc._cython.cygrpc._next_call_event()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/threading.py:299, in Condition.__enter__(self)
#     296     self._lock._at_fork_reinit()
#     297     self._waiters.clear()
# --> 299 def __enter__(self):
#     300     return self._lock.__enter__()
#     302 def __exit__(self, *args):
#
# KeyboardInterrupt:
