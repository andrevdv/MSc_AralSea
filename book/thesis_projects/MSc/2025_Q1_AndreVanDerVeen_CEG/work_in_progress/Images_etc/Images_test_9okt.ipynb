# %%
from grpc4bmi.bmi_client_singularity import BmiClientSingularity

model = BmiClientSingularity('/home/avandervee3/leakybucket_henk.sif', work_dir='/tmp')
print(model.get_component_name())
del model
# Out:
# leakybucket_versie_henk

# %%
from grpc4bmi.bmi_client_singularity import BmiClientSingularity

model = BmiClientSingularity('/home/avandervee3/pcrglobwb-grpc4bmi:setters_update.sif', work_dir='/tmp')
print(model.get_component_name())
del model
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 from grpc4bmi.bmi_client_singularity import BmiClientSingularity
# ----> 3 model = BmiClientSingularity('/home/avandervee3/pcrglobwb-grpc4bmi:setters_update.sif', work_dir='/tmp')
#       4 print(model.get_component_name())
#       5 del model
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_client_singularity.py:251, in __init__(self, image, work_dir, input_dirs, delay, timeout, capture_logs)
#     245 if returncode is not None:
#     246     raise DeadContainerException(
#     247         f'singularity container {image} prematurely exited with code {returncode}',
#     248         returncode,
#     249         self.logs()
#     250     )
# --> 251 super(BmiClientSingularity, self).__init__(BmiClient.create_grpc_channel(port=port, host=host), timeout=timeout)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc4bmi/bmi_grpc_client.py:74, in BmiClient.__init__(self, channel, timeout, stub)
#      72     self.stub = bmi_pb2_grpc.BmiServiceStub(c)
#      73     future = grpc.channel_ready_future(c)
# ---> 74     future.result(timeout=timeout)
#      75 else:
#      76     self.stub = stub
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_utilities.py:162, in _ChannelReadyFuture.result(self, timeout)
#     161 def result(self, timeout: Optional[float] = None) -> None:
# --> 162     self._block(timeout)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/grpc/_utilities.py:102, in _ChannelReadyFuture._block(self, timeout)
#     100 else:
#     101     if until is None:
# --> 102         self._condition.wait()
#     103     else:
#     104         remaining = until - time.time()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/threading.py:355, in Condition.wait(self, timeout)
#     353 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     354     if timeout is None:
# --> 355         waiter.acquire()
#     356         gotit = True
#     357     else:
#
# KeyboardInterrupt:
