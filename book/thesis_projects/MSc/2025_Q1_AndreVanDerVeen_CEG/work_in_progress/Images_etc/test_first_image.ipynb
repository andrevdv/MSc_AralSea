# %% [markdown]
# # test with super basic image/container

# %%
import ewatercycle.analysis
import ewatercycle.models
from ewatercycle.container import ContainerImage

# %%
from grpc4bmi.bmi_client_singularity import BmiClientSingularity
import os

# Make sure the work_dir exists and is writable
work_dir = '/tmp/bmi_test'
os.makedirs(work_dir, exist_ok=True)

# Path to your .sif container
sif_path = '/home/avandervee3/myfirstbmi.sif'

model = BmiClientSingularity(
    sif_path,
    work_dir=work_dir,
)

# Print component name
print("Component name:", model.get_component_name())

# Close the client
del model

# %%
from grpc4bmi.bmi_client_singularity import BmiClientSingularity

model = BmiClientSingularity(
    '/home/avandervee3/myfirstbmi.sif',
    work_dir='/tmp',
)
print(model.get_component_name())
del model
