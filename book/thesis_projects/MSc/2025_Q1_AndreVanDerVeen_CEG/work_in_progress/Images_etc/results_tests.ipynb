# %%
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
from ewatercycle.observation.grdc import get_grdc_data

ds = get_grdc_data(2817100,
                   '1900-01-01T00:00Z',
                   '2001-01-01T00:00Z',
                   data_home='/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Test_Aral/')

# %%
from ewatercycle.observation.grdc import get_grdc_data

ds_kerki = get_grdc_data(2617110,
                   '1900-01-01T00:00Z',
                   '2001-01-01T00:00Z',
                   data_home='/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Test_Aral/')

# %%
ds['streamflow'].sel(time=slice('1960', '1961')).plot(label='GRDC Chatly')

# %%
#file_name = '/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Test_Aral/pcrglobwb_20250930_091104/netcdf/channelStorage_dailyTot_output.nc' 

file_name_1 = '/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Images_etc/Discharge_6080_no_agri.nc'
file_name_2 = '/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Images_etc/Discharge_6080.nc'
file_name_3 = '/home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/Images_etc/discharge_dailyTot_output.nc'

# %%
ds_1 = xr.open_dataset(file_name_1)


ds_2 = xr.open_dataset(file_name_2)
ds_3 = xr.open_dataset(file_name_3)

# %%
# get the first variable name
first_var = list(ds_1.data_vars)[0]

# select that variable and last timestep
da_1 = ds_1[first_var].isel(time=-1)


#da_1 = ds_1[0].isel(time =-1)


da_1.plot(cmap="coolwarm", robust=True, size=5)

#plt.title(str(da["valid_time"].values))  # extract timestamp from coords
#plt.savefig('ERA5_pr_1988-12-22_21UTC.png')
plt.show()

# %%
# get the first variable name
first_var_2 = list(ds_2.data_vars)[0]

# select that variable and last timestep
da_2 = ds_2[first_var_2].isel(time=-1)


#da_1 = ds_1[0].isel(time =-1)


da_2.plot(cmap="coolwarm", robust=True, size=5)

#plt.title(str(da["valid_time"].values))  # extract timestamp from coords
#plt.savefig('ERA5_pr_1988-12-22_21UTC.png')
plt.show()

# %%
# get the first variable name
first_var_3 = list(ds_3.data_vars)[0]

# select that variable and last timestep
da_3 = ds_3[first_var_3].isel(time=-1)


#da_1 = ds_1[0].isel(time =-1)


da_3.plot(cmap="coolwarm", robust=True, size=5)

#plt.title(str(da["valid_time"].values))  # extract timestamp from coords
#plt.savefig('ERA5_pr_1988-12-22_21UTC.png')
plt.show()

# %%
da_slice = ds_1[first_var].sel(lat=42.35144950637272,lon=59.6170672781565, method="nearest")
da_slice_kerki = ds_1[first_var].sel(lat=37.84142225056401,lon=65.23396486873717, method="nearest")

#37.84142225056401, 65.23396486873717 Kerki
da_slice.plot()
da_slice_kerki.plot()
plt.title('discharge 30min - near GRDC station Chatli')
plt.grid()
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
da2_slice = ds_2[first_var_2].sel(lat=42.35144950637272,lon=59.6170672781565, method="nearest")
da2_slice_kerki = ds_2[first_var_2].sel(lat=37.84142225056401,lon=65.23396486873717, method="nearest")

#37.84142225056401, 65.23396486873717 Kerki
da2_slice.plot()
da2_slice_kerki.plot()
plt.title('discharge 30min - near GRDC station Chatli')
plt.grid()
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
da3_slice = ds_3[first_var_3].sel(lat=42.35144950637272,lon=59.6170672781565, method="nearest")
da3_slice_kerki = ds_3[first_var_3].sel(lat=37.84142225056401,lon=65.23396486873717, method="nearest")

#37.84142225056401, 65.23396486873717 Kerki
da3_slice.plot()
da3_slice_kerki.plot()
plt.title('discharge 30min - near GRDC station Chatli')
plt.grid()
plt.xlabel('Date')
# Out:
# Text(0.5, 0, 'Date')

# %%
fig, ax = plt.subplots()
da3_slice_kerki.sel(time=slice('1962', '1962')).plot(ax=ax, label='PCR_GLOBWB_30min')
da2_slice_kerki.sel(time=slice('1962', '1962')).plot(ax=ax, label='PCR_GLOBWB_agri')
da_slice_kerki.sel(time=slice('1962', '1962')).plot(ax=ax, label='PCR_GLOBWB_no_agri')
ds['streamflow'].sel(time=slice('1962', '1962')).plot(ax=ax, label='GRDC Data')

ax.legend()
ax.grid()
ax.set_title('Discharges at GRDC station Chatly')
# Out:
# Text(0.5, 1.0, 'Discharges at GRDC station Chatly')

# %%
fig, ax = plt.subplots()
#da3_slice.sel(time=slice('1962', '1962')).plot(ax=ax, label='PCR_GLOBWB_30min')
da2_slice.sel(time=slice('1962', '1962')).plot(ax=ax, label='PCR_GLOBWB_30min_agri')
da_slice.sel(time=slice('1962', '1962')).plot(ax=ax, label='PCR_GLOBWB_30min_no_agri')
ds_kerki['streamflow'].sel(time=slice('1962', '1962')).plot(ax=ax, label='GRDC Data')

ax.legend()
ax.grid()
ax.set_title('Discharges at GRDC station Kerki')
# Out:
# Text(0.5, 1.0, 'Discharges at GRDC station Kerki')
