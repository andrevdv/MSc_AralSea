# %%
from grpc4bmi.bmi_client_singularity import BmiClientSingularity

image = '<docker image name of grpc4bmi server of a bmi model>'
#input_dir = '<directory with models input data files>'
#work_dir = '<directory where model can write output files>'
client = BmiClientSingularity(image)

 # Interact with model
client.initialize('<absolute path to config file in the input directory>')

# Stop container
del client

# %%
from grpc4bmi.bmi_client_singularity import BmiClientSingularity

model = BmiClientSingularity('/home/avandervee3/pcrglobwb-grpc4bmi:setters_update.sif', work_dir='/tmp')

del model

# %%
from grpc4bmi.bmi_client_docker import BmiClientDocker
model = BmiClientDocker('/home/avandervee3/hbv-np-grpc4bmi_andre.sif', work_dir='/tmp', delay=1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# ...

# %%
import subprocess

cmd = [
    'apptainer', 'exec',
    '/home/avandervee3/hbv-np-grpc4bmi_andre.sif',
    'python', 'my_model_script.py'
]
subprocess.run(cmd)
# Out:
# FATAL:   "python": executable file not found in $PATH
# CompletedProcess(args=['apptainer', 'exec', '/home/avandervee3/hbv-np-grpc4bmi_andre.sif', 'python', 'my_model_script.py'], returncode=255)
