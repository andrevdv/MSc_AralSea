# %% [markdown]
# ## Notebook to experiment with bias correction
# - ERA5
# - CMIP
# - GRDC
#
# for now 1d
#
# -----------------
# #### To Do
#
# - cumulative dist function
# - map between ERA5 and CMIP
# - make .py function
# - test?
