# %% [markdown]
# # description
#
# this notebook is for testing some of the .py files
#
# * paths

# %%
# setup imports
import sys
from pathlib import Path

PROJECT_ROOT = Path().resolve().parents[2]  # pas aan als notebook dieper/dichter zit
sys.path.append(str(PROJECT_ROOT))

from src.paths import *
from src.plotting import plot_dem_map

# %%
print("Project root:", PROJECT_ROOT)
print("Root folder:", ROOT)
print("Forcing folder:", FORCING_FOLDER)
print("Run:", FORCING_CMIP_HIST)
# Out:
# Project root: /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress
# Root folder: /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress
# Forcing folder: /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/forcing
# Run: /home/avandervee3/MSc_AralSea/book/thesis_projects/MSc/2025_Q1_AndreVanDerVeen_CEG/work_in_progress/forcing/output/CMIP_HIST

# %%
from src.forcing import *
# Out:
# /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498

# %%
experiment_start_date = "1950-01-01T00:00:00Z"
experiment_end_date = "1960-12-31T00:00:00Z"

#ERA5_forcing = setup_forcing("Kerki_GRDC", "ERA5", experiment_start_date, experiment_end_date)
#CMIP_forcing = setup_CMIP_historical_forcing("Kerki_GRDC", experiment_start_date, experiment_end_date)

# %%
#ERA5_forcing_loaded = load_lumped_forcing("Kerki_GRDC", "ERA5")
#CMIP_forcing_loaded = load_lumped_forcing("Kerki_GRDC", "CMIP_HIST")

#plot_ERA5_forcing(ERA5_forcing_loaded)
#plot_ERA5_forcing(CMIP_forcing_loaded)

# %%
path_terrain = "/data/shared/parameter-sets/pcrglobwb_global/global_05min/landSurface/topography/topography_parameters_5_arcmin_october_2015.nc"
# Open the NetCDF file
ds = xr.open_dataset(path_terrain)

# Slice the dataset for the area of interest
dem_subset = ds['dem_average'].sel(
    lat=slice(54, 32),  # xarray lat usually goes from high to low
    lon=slice(55, 83)
)

print(dem_subset)
# Out:
# <xarray.DataArray 'dem_average' (lat: 264, lon: 336)> Size: 355kB
# [88704 values with dtype=float32]
# Coordinates:
#   * lat      (lat) float32 1kB 53.96 53.88 53.79 53.71 ... 32.21 32.12 32.04
#   * lon      (lon) float32 1kB 55.04 55.12 55.21 55.29 ... 82.79 82.88 82.96
# Attributes:
#     standard_name:  dem_average
#     long_name:      dem_average
#     units:          m

# %%
fig, ax = plot_dem_map(
    dem_subset,
    shapefile = SHAPEFILES/"AralSea_basin"/"AralSea_basin.shp",
    title="Digital Elevation Map of Study Area",
    cmap = 'terrain'
)
