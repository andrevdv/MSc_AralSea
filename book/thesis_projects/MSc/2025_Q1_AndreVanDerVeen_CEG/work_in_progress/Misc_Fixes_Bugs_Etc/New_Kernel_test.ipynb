# %%
# -------------------------------
# PCR-GLOBWB Branch / Environment Check
# -------------------------------

import sys
import os

# 1️⃣ Voeg de juiste model folder toe aan sys.path
model_path = "/home/avandervee3/PCR-GLOBWB_model/model"
if model_path not in sys.path:
    sys.path.insert(0, model_path)
    print(f"Added {model_path} to sys.path")

# 2️⃣ Test import van Cython module imagemean
try:
    import imagemean
    print("✅ imagemean imported successfully")
    print("Location:", imagemean.__file__)
except ModuleNotFoundError:
    print("❌ imagemean module NOT found. Build it with setup.py first!")

# 3️⃣ Test import van grpc4bmi
try:
    import grpc4bmi
    print("✅ grpc4bmi imported successfully")
except ModuleNotFoundError:
    print("❌ grpc4bmi module NOT found. Install it in your environment!")

# 4️⃣ Check huidige sys.path
print("\nCurrent sys.path:")
for p in sys.path:
    print(" -", p)
# Out:
# ✅ imagemean imported successfully
# Location: /home/avandervee3/PCR-GLOBWB_model/model/imagemean.cpython-312-x86_64-linux-gnu.so
# ✅ grpc4bmi imported successfully
#
# Current sys.path:
#  - /home/avandervee3/PCR-GLOBWB_model/model
#  - /home/avandervee3/.conda/envs/pcrglobwb_fixes25/lib/python312.zip
#  - /home/avandervee3/.conda/envs/pcrglobwb_fixes25/lib/python3.12
#  - /home/avandervee3/.conda/envs/pcrglobwb_fixes25/lib/python3.12/lib-dynload
#  -
#  - /home/avandervee3/.conda/envs/pcrglobwb_fixes25/lib/python3.12/site-packages

# %%
import matplotlib.pyplot as plt
from cartopy import crs
from cartopy import feature as cfeature
from rich import print
import pandas as pd
import xarray as xr
from pathlib import Path
from datetime import datetime
from ipywidgets import IntProgress
from IPython.display import display
import fiona
import shapely.geometry
from pyproj import Geod

import ewatercycle.forcing
import ewatercycle.models
import ewatercycle.parameter_sets
# Out:
# /home/avandervee3/.conda/envs/pcrglobwb_fixes25/lib/python3.12/site-packages/esmvalcore/experimental/_warnings.py:13: UserWarning:
#   Thank you for trying out the new ESMValCore API.
#   Note that this API is experimental and may be subject to change.
#   More info: https://github.com/ESMValGroup/ESMValCore/issues/498
